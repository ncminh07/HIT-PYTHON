# %%
x = 10
name = "HIT"
website = "apple.com"
x = y = 99
print( " x  = "  , x)
print(type(y)) #lấy kiểu dữ liệu của biến y
print(f"x = y = {x}")
x = 9
if x > 0 :
    print("x la so duong")
elif x < 0 :
    print("x la so am")
else:
    print("x la so khong")
# Out:
#  x  =  99
# <class 'int'>
# x = y = 99
# x la so duong
